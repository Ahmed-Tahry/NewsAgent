# %%
pip install google-genai
# Out:
# Requirement already satisfied: google-genai in /usr/local/lib/python3.12/dist-packages (1.41.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (4.11.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-genai) (2.38.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (2.11.10)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from google-genai) (8.5.0)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (4.9.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-genai) (0.6.1)

# %%
# To run this code you need to install the following dependencies:


import os
import json
import time
from google import genai
from google.genai import types
from google.colab import userdata

OUTPUT_FILE = "synthetic_news_dataset.jsonl"
NUM_EXAMPLES = 300  # Change this to generate more examples
RETRY_LIMIT = 3     # Number of retries per failed generation
SLEEP_BETWEEN = 5
PROMPT = """
You are an expert analyst and dataset generator. Your task is to create synthetic historical news data for AI training.
Generate similar example below with diffrent domain using real world articles and exact same deep analysis and follow the exact jsonl srtucture  :

{
"article_id": "A6001",
"published_at": "2025-10-08T00:00:00Z",
"article_text": "Japanese investing conglomerate SoftBank Group is buying a robotics company as the financial behemoth says physical AI is its next frontier. SoftBank announced on Wednesday that it has acquired Zurich, Switzerland-based ABB Group’s robotics business unit for $5.375 billion. The deal is subject to regulatory approval; SoftBank predicts the deal will close in mid-to-late 2026 according to a press release. Sami Atiya, the head of the division, will exit the company once the acquisition is complete, per ABB Group. ABB’s robotics business employs roughly 7,000 people and sells a variety of robots and equipment, designed for tasks like picking, cleaning, and painting. The company made $2.3 billion in revenue in 2024, representing 7% of ABB’s overall revenue. ABB announced plans to spin out its robotics group in April. SoftBank said it hopes to be able to “reignite” sales at ABB’s robotics spinoff. The organization’s 2024 revenue was only $2.3 billion, down from $2.5 billion the previous year. SoftBank has been building up its investments and holdings in robotics over the last few years. The entity has invested in companies including more legacy players like AutoStore and startups including Skild AI and Agile Robots. The firm also launched its own robotics platform, SoftBank Robotics Group, in 2014. “SoftBank’s next frontier is physical AI,” Masayoshi Son, the chairman and CEO of SoftBank said in the company’s press release. “Together with ABB Robotics, we will unite world-class technology and talent under our shared vision to fuse Artificial Super Intelligence and robotics — driving a groundbreaking evolution that will propel humanity forward.” Robotics is one of four focus areas for SoftBank, together with AI chips, AI data centers, and energy. “The center of the ‘Information Revolution’ has evolved from personal computers, the internet, and broadband to smartphones, and has now entered a new phase led by artificial intelligence,” SoftBank said in its press release. “In this context, [SoftBank Group] has declared its mission to realize artificial super intelligence (ASI) for the advancement of humanity.”",
"entities": [
{"entity_id": "B-ORG-1", "name": "SoftBank Group", "type": "company", "profile_text": "Japanese multinational holding company known for investments in tech and AI. Led by Masayoshi Son, focused on ASI and physical AI.", "last_updated": "2025-10-08"},
{"entity_id": "B-ORG-2", "name": "ABB Group", "type": "company", "profile_text": "Swiss-Swedish multinational corporation in robotics, power, heavy electrical equipment, and automation technology.", "last_updated": "2025-10-08"},
{"entity_id": "B-PER-1", "name": "Masayoshi Son", "type": "person", "profile_text": "Chairman and CEO of SoftBank Group, visionary investor in AI and robotics.", "last_updated": "2025-10-08"},
{"entity_id": "B-PER-2", "name": "Sami Atiya", "type": "person", "profile_text": "Former head of ABB's robotics division, exiting post-acquisition.", "last_updated": "2025-10-08"},
{"entity_id": "B-LOC-1", "name": "Zurich", "type": "place", "profile_text": "Swiss city, headquarters of ABB Group.", "last_updated": "2025-10-08"}
],
"gold_output": {
"concise_summary": "SoftBank Group's $5.375B acquisition of ABB's robotics unit accelerates its physical AI strategy, aiming to 'reignite' $2.3B revenue stream amid declining sales, with closure expected mid-2026.",
"expanded_analysis": "This deal marks SoftBank's bold pivot to physical AI, fusing ABB's industrial robotics expertise (7,000 employees, $2.3B 2024 revenue down 8% YoY) with its ASI vision. By acquiring a mature player like ABB Robotics—focused on picking, cleaning, and painting tasks—SoftBank addresses its robotics portfolio gaps, complementing investments in startups like Skild AI ($500M) and Agile Robots. The $5.375B price (premium over ABB's $3.4B valuation) reflects synergies in AI chips/data centers, potentially yielding 20-30% efficiency gains via ASI integration. Risks include regulatory delays (e.g., EU antitrust scrutiny on tech consolidation) and talent exodus post-Sami Atiya's departure, but SoftBank's track record (e.g., Arm Holdings) suggests strong execution, targeting the $100B+ robotics market growing at 15% CAGR.",
"impact_forecast": [
{"impact_type": "PORTFOLIO_SYNERGY", "horizon": "SHORT_TERM", "magnitude": "HIGH", "probability": 0.85, "rationale": "ABB's industrial robots integrate with SoftBank's AI investments (e.g., Skild AI), boosting deployment in manufacturing by 25%, reversing ABB's revenue decline through 'reignition' strategies."},
{"impact_type": "MARKET_CONSOLIDATION", "horizon": "MEDIUM_TERM", "magnitude": "MEDIUM", "probability": 0.7, "rationale": "Accelerates robotics M&A wave, pressuring competitors like Boston Dynamics, but invites regulatory hurdles (e.g., 6-12 month EU review), potentially delaying $1B+ synergies."},
{"impact_type": "INNOVATION_ACCELERATION", "horizon": "LONG_TERM", "magnitude": "HIGH", "probability": 0.75, "rationale": "Fuses ASI with robotics for 'humanity advancement' (per Masayoshi Son), enabling breakthroughs in autonomous systems, capturing 10-15% of $210B global robotics market by 2030."}
],
"scenarios": [
{"probability": 0.65, "outcome": "Synergistic Breakthrough: Regulatory approval by mid-2026 enables rapid ASI-robotics fusion, driving 40% revenue growth and positioning SoftBank as physical AI leader, with $2B+ annual synergies."},
{"probability": 0.25, "outcome": "Regulatory Delay: Antitrust scrutiny extends closure to 2027, causing $500M opportunity costs and talent flight (20% of 7,000 employees), stalling innovation momentum."},
{"probability": 0.1, "outcome": "Integration Failure: Cultural clashes post-acquisition lead to 15% revenue drop in first year, forcing divestiture and eroding SoftBank's ASI credibility in robotics."}
],
"confidence": 0.88,
"evidence_refs": ["B-ORG-1", "B-ORG-2", "B-PER-1", "B-PER-2"]
}
}

Generate **one full synthetic historical news example**.
"""

def generate_single_example(client, model, prompt_text):
    """Generate a single JSON example, retrying parsing if needed."""
    contents = [
        types.Content(
            role="user",
            parts=[types.Part.from_text(text=prompt_text)],
        ),
    ]
    generate_content_config = types.GenerateContentConfig(
        thinking_config=types.ThinkingConfig(thinking_budget=-1),
    )

    result_text = ""
    for chunk in client.models.generate_content_stream(
        model=model,
        contents=contents,
        config=generate_content_config,
    ):
        result_text += chunk.text

    # Try direct parse
    try:
        return json.loads(result_text)
    except json.JSONDecodeError:
        # Try extracting a JSON substring
        start = result_text.find("{")
        end = result_text.rfind("}") + 1
        if start != -1 and end != -1:
            try:
                return json.loads(result_text[start:end])
            except json.JSONDecodeError:
                pass
        print("⚠️ JSON parse failed.")
        return None


def generate_dataset():
    """Main loop: generates NUM_EXAMPLES, with retry and resume."""
    api_key = userdata.get("GEMINI_API_KEY")
    client = genai.Client(api_key=api_key)
    model = "gemini-2.5-pro"

    # Resume mode — load existing file if present
    generated = 0
    if os.path.exists(OUTPUT_FILE):
        with open(OUTPUT_FILE, "r", encoding="utf-8") as f:
            generated = sum(1 for _ in f)
        print(f"✅ Found {generated} existing samples, resuming from there.")

    with open(OUTPUT_FILE, "a", encoding="utf-8") as f:
        for i in range(generated, NUM_EXAMPLES):
            print(f"\n📰 Generating example {i+1}/{NUM_EXAMPLES}...")

            for attempt in range(1, RETRY_LIMIT + 1):
                try:
                    example = generate_single_example(client, model, PROMPT)
                    if example:
                        f.write(json.dumps(example, ensure_ascii=False) + "\n")
                        f.flush()  # Save immediately
                        print(f"✅ Example {i+1} saved.")
                        break
                    else:
                        raise ValueError("Invalid output format.")
                except Exception as e:
                    print(f"⚠️ Attempt {attempt} failed: {e}")
                    if attempt == RETRY_LIMIT:
                        print("❌ Skipping this example after max retries.")
                time.sleep(SLEEP_BETWEEN)

    print(f"\n🎉 Dataset generation complete. Saved to {OUTPUT_FILE}")

if __name__ == "__main__":
    generate_dataset()
# Out:
# ✅ Found 1 existing samples, resuming from there.
#
# 📰 Generating example 2/300...
# ✅ Example 2 saved.
#
# 📰 Generating example 3/300...
# ✅ Example 3 saved.
#
# 📰 Generating example 4/300...
# ✅ Example 4 saved.
#
# 📰 Generating example 5/300...
# ✅ Example 5 saved.
#
# 📰 Generating example 6/300...
# ✅ Example 6 saved.
#
# 📰 Generating example 7/300...
# ✅ Example 7 saved.
#
# 📰 Generating example 8/300...
# ✅ Example 8 saved.
#
# 📰 Generating example 9/300...
# ✅ Example 9 saved.
#
# 📰 Generating example 10/300...
# ✅ Example 10 saved.
#
# 📰 Generating example 11/300...
# ⚠️ JSON parse failed.
# ⚠️ Attempt 1 failed: Invalid output format.
# ✅ Example 11 saved.
#
# 📰 Generating example 12/300...
# ✅ Example 12 saved.
#
# 📰 Generating example 13/300...
# ✅ Example 13 saved.
#
# 📰 Generating example 14/300...
# ✅ Example 14 saved.
#
# 📰 Generating example 15/300...
# ✅ Example 15 saved.
#
# 📰 Generating example 16/300...
# ✅ Example 16 saved.
#
# 📰 Generating example 17/300...
# ✅ Example 17 saved.
#
# 📰 Generating example 18/300...
# ✅ Example 18 saved.
#
# 📰 Generating example 19/300...
# ✅ Example 19 saved.
#
# 📰 Generating example 20/300...
# ✅ Example 20 saved.
#
# 📰 Generating example 21/300...
# ✅ Example 21 saved.
#
# 📰 Generating example 22/300...
# ✅ Example 22 saved.
#
# 📰 Generating example 23/300...
# ⚠️ Attempt 1 failed: can only concatenate str (not "NoneType") to str
# ✅ Example 23 saved.
#
# 📰 Generating example 24/300...
# ✅ Example 24 saved.
#
# 📰 Generating example 25/300...
# ✅ Example 25 saved.
#
# 📰 Generating example 26/300...
# ✅ Example 26 saved.
#
# 📰 Generating example 27/300...
# ⚠️ JSON parse failed.
# ⚠️ Attempt 1 failed: Invalid output format.
# ✅ Example 27 saved.
#
# 📰 Generating example 28/300...
# ✅ Example 28 saved.
#
# 📰 Generating example 29/300...
# ✅ Example 29 saved.
#
# 📰 Generating example 30/300...
# ✅ Example 30 saved.
#
# 📰 Generating example 31/300...
# ✅ Example 31 saved.
#
# 📰 Generating example 32/300...
# ✅ Example 32 saved.
#
# 📰 Generating example 33/300...
# ✅ Example 33 saved.
#
# 📰 Generating example 34/300...
# ✅ Example 34 saved.
#
# 📰 Generating example 35/300...
# ✅ Example 35 saved.
#
# 📰 Generating example 36/300...
# ✅ Example 36 saved.
#
# 📰 Generating example 37/300...
# ⚠️ Attempt 1 failed: can only concatenate str (not "NoneType") to str
# ✅ Example 37 saved.
#
# 📰 Generating example 38/300...
# ✅ Example 38 saved.
#
# 📰 Generating example 39/300...
# ✅ Example 39 saved.
#
# 📰 Generating example 40/300...
# ✅ Example 40 saved.
#
# 📰 Generating example 41/300...
# ✅ Example 41 saved.
#
# 📰 Generating example 42/300...
# ✅ Example 42 saved.
#
# 📰 Generating example 43/300...
# ✅ Example 43 saved.
#
# 📰 Generating example 44/300...
# ✅ Example 44 saved.
#
# 📰 Generating example 45/300...
# ✅ Example 45 saved.
#
# 📰 Generating example 46/300...
# ✅ Example 46 saved.
#
# 📰 Generating example 47/300...
# ✅ Example 47 saved.
#
# 📰 Generating example 48/300...
# ✅ Example 48 saved.
#
# 📰 Generating example 49/300...
# ✅ Example 49 saved.
#
# 📰 Generating example 50/300...
# ✅ Example 50 saved.
#
# 📰 Generating example 51/300...
# ✅ Example 51 saved.
#
# 📰 Generating example 52/300...
# ✅ Example 52 saved.
#
# 📰 Generating example 53/300...
# ✅ Example 53 saved.
#
# 📰 Generating example 54/300...
# ✅ Example 54 saved.
#
# 📰 Generating example 55/300...
# ⚠️ JSON parse failed.
# ⚠️ Attempt 1 failed: Invalid output format.
# ✅ Example 55 saved.
#
# 📰 Generating example 56/300...
# ✅ Example 56 saved.
#
# 📰 Generating example 57/300...
# ✅ Example 57 saved.
#
# 📰 Generating example 58/300...
# ⚠️ Attempt 1 failed: can only concatenate str (not "NoneType") to str
# ✅ Example 58 saved.
#
# 📰 Generating example 59/300...
# ✅ Example 59 saved.
#
# 📰 Generating example 60/300...
# ✅ Example 60 saved.
#
# 📰 Generating example 61/300...
# ✅ Example 61 saved.
#
# 📰 Generating example 62/300...
# ✅ Example 62 saved.
#
# 📰 Generating example 63/300...
# ⚠️ Attempt 1 failed: can only concatenate str (not "NoneType") to str
# ✅ Example 63 saved.
#
# 📰 Generating example 64/300...
# ✅ Example 64 saved.
#
# 📰 Generating example 65/300...
# ✅ Example 65 saved.
#
# 📰 Generating example 66/300...
# ✅ Example 66 saved.
#
# 📰 Generating example 67/300...
# ✅ Example 67 saved.
#
# 📰 Generating example 68/300...
# ✅ Example 68 saved.
#
# 📰 Generating example 69/300...
# ✅ Example 69 saved.
#
# 📰 Generating example 70/300...
# ✅ Example 70 saved.
#
# 📰 Generating example 71/300...
# ✅ Example 71 saved.
#
# 📰 Generating example 72/300...
# ✅ Example 72 saved.
#
# 📰 Generating example 73/300...
# ✅ Example 73 saved.
#
# 📰 Generating example 74/300...
# ✅ Example 74 saved.
#
# 📰 Generating example 75/300...
# ✅ Example 75 saved.
#
# 📰 Generating example 76/300...
# ✅ Example 76 saved.
#
# 📰 Generating example 77/300...
# ✅ Example 77 saved.
#
# 📰 Generating example 78/300...
# ✅ Example 78 saved.
#
# 📰 Generating example 79/300...
# ✅ Example 79 saved.
#
# 📰 Generating example 80/300...
# ✅ Example 80 saved.
#
# 📰 Generating example 81/300...
# ✅ Example 81 saved.
#
# 📰 Generating example 82/300...
# ✅ Example 82 saved.
#
# 📰 Generating example 83/300...
# ✅ Example 83 saved.
#
# 📰 Generating example 84/300...
# ✅ Example 84 saved.
#
# 📰 Generating example 85/300...
# ✅ Example 85 saved.
#
# 📰 Generating example 86/300...
# ✅ Example 86 saved.
#
# 📰 Generating example 87/300...
# ✅ Example 87 saved.
#
# 📰 Generating example 88/300...
# ✅ Example 88 saved.
#
# 📰 Generating example 89/300...
# ✅ Example 89 saved.
#
# 📰 Generating example 90/300...
# ✅ Example 90 saved.
#
# 📰 Generating example 91/300...
# ✅ Example 91 saved.
#
# 📰 Generating example 92/300...
# ✅ Example 92 saved.
#
# 📰 Generating example 93/300...
# ✅ Example 93 saved.
#
# 📰 Generating example 94/300...
# ✅ Example 94 saved.
#
# 📰 Generating example 95/300...
# ✅ Example 95 saved.
#
# 📰 Generating example 96/300...
# ✅ Example 96 saved.
#
# 📰 Generating example 97/300...
# ✅ Example 97 saved.
#
# 📰 Generating example 98/300...
# ✅ Example 98 saved.
#
# 📰 Generating example 99/300...
# ✅ Example 99 saved.
#
# 📰 Generating example 100/300...
# ✅ Example 100 saved.
#
# 📰 Generating example 101/300...
# ✅ Example 101 saved.
#
# 📰 Generating example 102/300...
# ✅ Example 102 saved.
#
# 📰 Generating example 103/300...
# ✅ Example 103 saved.
#
# 📰 Generating example 104/300...
# ✅ Example 104 saved.
#
# 📰 Generating example 105/300...
# ✅ Example 105 saved.
#
# 📰 Generating example 106/300...
# ✅ Example 106 saved.
#
# 📰 Generating example 107/300...
# ✅ Example 107 saved.
#
# 📰 Generating example 108/300...
# ✅ Example 108 saved.
#
# 📰 Generating example 109/300...
# ✅ Example 109 saved.
#
# 📰 Generating example 110/300...
# ✅ Example 110 saved.
#
# 📰 Generating example 111/300...
# ✅ Example 111 saved.
#
# 📰 Generating example 112/300...
# ✅ Example 112 saved.
#
# 📰 Generating example 113/300...
# ✅ Example 113 saved.
#
# 📰 Generating example 114/300...
# ✅ Example 114 saved.
#
# 📰 Generating example 115/300...
# ✅ Example 115 saved.
#
# 📰 Generating example 116/300...
# ✅ Example 116 saved.
#
# 📰 Generating example 117/300...
# ✅ Example 117 saved.
#
# 📰 Generating example 118/300...
# ✅ Example 118 saved.
#
# 📰 Generating example 119/300...
# ✅ Example 119 saved.
#
# 📰 Generating example 120/300...
# ✅ Example 120 saved.
#
# 📰 Generating example 121/300...
# ✅ Example 121 saved.
#
# 📰 Generating example 122/300...
# ✅ Example 122 saved.
#
# 📰 Generating example 123/300...
# ✅ Example 123 saved.
#
# 📰 Generating example 124/300...
# ✅ Example 124 saved.
#
# 📰 Generating example 125/300...
# ✅ Example 125 saved.
#
# 📰 Generating example 126/300...
# ✅ Example 126 saved.
#
# 📰 Generating example 127/300...
# ✅ Example 127 saved.
#
# 📰 Generating example 128/300...
# ✅ Example 128 saved.
#
# 📰 Generating example 129/300...
# ✅ Example 129 saved.
#
# 📰 Generating example 130/300...
# ✅ Example 130 saved.
#
# 📰 Generating example 131/300...
# ✅ Example 131 saved.
#
# 📰 Generating example 132/300...
# ✅ Example 132 saved.
#
# 📰 Generating example 133/300...
# ✅ Example 133 saved.
#
# 📰 Generating example 134/300...
# ⚠️ Attempt 1 failed: can only concatenate str (not "NoneType") to str
# ✅ Example 134 saved.
#
# 📰 Generating example 135/300...
# ✅ Example 135 saved.
#
# 📰 Generating example 136/300...
# ✅ Example 136 saved.
#
# 📰 Generating example 137/300...
# ✅ Example 137 saved.
#
# 📰 Generating example 138/300...
# ✅ Example 138 saved.
#
# 📰 Generating example 139/300...
# ✅ Example 139 saved.
#
# 📰 Generating example 140/300...
# ✅ Example 140 saved.
#
# 📰 Generating example 141/300...
# ✅ Example 141 saved.
#
# 📰 Generating example 142/300...
# ✅ Example 142 saved.
#
# 📰 Generating example 143/300...
# ✅ Example 143 saved.
#
# 📰 Generating example 144/300...
# ⚠️ JSON parse failed.
# ⚠️ Attempt 1 failed: Invalid output format.
# ✅ Example 144 saved.
#
# 📰 Generating example 145/300...
# ⚠️ Attempt 1 failed: can only concatenate str (not "NoneType") to str
# ✅ Example 145 saved.
#
# 📰 Generating example 146/300...
# ✅ Example 146 saved.
#
# 📰 Generating example 147/300...
# ✅ Example 147 saved.
#
# 📰 Generating example 148/300...
# ✅ Example 148 saved.
#
# 📰 Generating example 149/300...
# ✅ Example 149 saved.
#
# 📰 Generating example 150/300...
# ✅ Example 150 saved.
#
# 📰 Generating example 151/300...
# ✅ Example 151 saved.
#
# 📰 Generating example 152/300...
# ✅ Example 152 saved.
#
# 📰 Generating example 153/300...
# ✅ Example 153 saved.
#
# 📰 Generating example 154/300...
# ✅ Example 154 saved.
#
# 📰 Generating example 155/300...
# ✅ Example 155 saved.
#
# 📰 Generating example 156/300...
# ✅ Example 156 saved.
#
# 📰 Generating example 157/300...
# ✅ Example 157 saved.
#
# 📰 Generating example 158/300...
# ✅ Example 158 saved.
#
# 📰 Generating example 159/300...
# ✅ Example 159 saved.
#
# 📰 Generating example 160/300...
# ✅ Example 160 saved.
#
# 📰 Generating example 161/300...
# ✅ Example 161 saved.
#
# 📰 Generating example 162/300...
# ✅ Example 162 saved.
#
# 📰 Generating example 163/300...
# ✅ Example 163 saved.
#
# 📰 Generating example 164/300...
# ✅ Example 164 saved.
#
# 📰 Generating example 165/300...
# ✅ Example 165 saved.
#
# 📰 Generating example 166/300...
# ✅ Example 166 saved.
#
# 📰 Generating example 167/300...
# ✅ Example 167 saved.
#
# 📰 Generating example 168/300...
# ✅ Example 168 saved.
#
# 📰 Generating example 169/300...
# ✅ Example 169 saved.
#
# 📰 Generating example 170/300...
# ✅ Example 170 saved.
#
# 📰 Generating example 171/300...
# ✅ Example 171 saved.
#
# 📰 Generating example 172/300...
# ✅ Example 172 saved.
#
# 📰 Generating example 173/300...
# ✅ Example 173 saved.
#
# 📰 Generating example 174/300...
# ✅ Example 174 saved.
#
# 📰 Generating example 175/300...
# ✅ Example 175 saved.
#
# 📰 Generating example 176/300...
# ⚠️ Attempt 1 failed: can only concatenate str (not "NoneType") to str
# ✅ Example 176 saved.
#
# 📰 Generating example 177/300...
# ✅ Example 177 saved.
#
# 📰 Generating example 178/300...
# ✅ Example 178 saved.
#
# 📰 Generating example 179/300...
# ✅ Example 179 saved.
#
# 📰 Generating example 180/300...
# ✅ Example 180 saved.
#
# 📰 Generating example 181/300...
# ✅ Example 181 saved.
#
# 📰 Generating example 182/300...
# ✅ Example 182 saved.
#
# 📰 Generating example 183/300...
# ✅ Example 183 saved.
#
# 📰 Generating example 184/300...
# ✅ Example 184 saved.
#
# 📰 Generating example 185/300...
# ✅ Example 185 saved.
#
# 📰 Generating example 186/300...
# ✅ Example 186 saved.
#
# 📰 Generating example 187/300...
# ✅ Example 187 saved.
#
# 📰 Generating example 188/300...
# ✅ Example 188 saved.
#
# 📰 Generating example 189/300...
# ✅ Example 189 saved.
#
# 📰 Generating example 190/300...
# ✅ Example 190 saved.
#
# 📰 Generating example 191/300...
# ✅ Example 191 saved.
#
# 📰 Generating example 192/300...
# ✅ Example 192 saved.
#
# 📰 Generating example 193/300...
# ✅ Example 193 saved.
#
# 📰 Generating example 194/300...
# ✅ Example 194 saved.
#
# 📰 Generating example 195/300...
# ✅ Example 195 saved.
#
# 📰 Generating example 196/300...
# ✅ Example 196 saved.
#
# 📰 Generating example 197/300...
# ✅ Example 197 saved.
#
# 📰 Generating example 198/300...
# ✅ Example 198 saved.
#
# 📰 Generating example 199/300...
# ✅ Example 199 saved.
#
# 📰 Generating example 200/300...
# ✅ Example 200 saved.
#
# 📰 Generating example 201/300...
# ✅ Example 201 saved.
#
# 📰 Generating example 202/300...
# ⚠️ Attempt 1 failed: can only concatenate str (not "NoneType") to str
# ✅ Example 202 saved.
#
# 📰 Generating example 203/300...
# ✅ Example 203 saved.
#
# 📰 Generating example 204/300...
# ✅ Example 204 saved.
#
# 📰 Generating example 205/300...
# ✅ Example 205 saved.
#
# 📰 Generating example 206/300...
# ✅ Example 206 saved.
#
# 📰 Generating example 207/300...
# ⚠️ Attempt 1 failed: can only concatenate str (not "NoneType") to str
# ✅ Example 207 saved.
#
# 📰 Generating example 208/300...
# ✅ Example 208 saved.
#
# 📰 Generating example 209/300...
# ✅ Example 209 saved.
#
# 📰 Generating example 210/300...
# ✅ Example 210 saved.
#
# 📰 Generating example 211/300...
# ✅ Example 211 saved.
#
# 📰 Generating example 212/300...
# ✅ Example 212 saved.
#
# 📰 Generating example 213/300...
# ✅ Example 213 saved.
#
# 📰 Generating example 214/300...
# ✅ Example 214 saved.
#
# 📰 Generating example 215/300...
# ✅ Example 215 saved.
#
# 📰 Generating example 216/300...
# ✅ Example 216 saved.
#
# 📰 Generating example 217/300...
# ⚠️ Attempt 1 failed: can only concatenate str (not "NoneType") to str
# ✅ Example 217 saved.
#
# 📰 Generating example 218/300...
# ✅ Example 218 saved.
#
# 📰 Generating example 219/300...
# ✅ Example 219 saved.
#
# 📰 Generating example 220/300...
# ✅ Example 220 saved.
#
# 📰 Generating example 221/300...
# ✅ Example 221 saved.
#
# 📰 Generating example 222/300...
# ⚠️ Attempt 1 failed: can only concatenate str (not "NoneType") to str
# ✅ Example 222 saved.
#
# 📰 Generating example 223/300...
# ✅ Example 223 saved.
#
# 📰 Generating example 224/300...
# ⚠️ Attempt 1 failed: can only concatenate str (not "NoneType") to str
# ✅ Example 224 saved.
#
# 📰 Generating example 225/300...
# ✅ Example 225 saved.
#
# 📰 Generating example 226/300...
# ✅ Example 226 saved.
#
# 📰 Generating example 227/300...
# ✅ Example 227 saved.
#
# 📰 Generating example 228/300...
# ✅ Example 228 saved.
#
# 📰 Generating example 229/300...
# ✅ Example 229 saved.
#
# 📰 Generating example 230/300...
# ✅ Example 230 saved.
#
# 📰 Generating example 231/300...
# ✅ Example 231 saved.
#
# 📰 Generating example 232/300...
# ✅ Example 232 saved.
#
# 📰 Generating example 233/300...
# ✅ Example 233 saved.
#
# 📰 Generating example 234/300...
# ✅ Example 234 saved.
#
# 📰 Generating example 235/300...
# ✅ Example 235 saved.
#
# 📰 Generating example 236/300...
# ✅ Example 236 saved.
#
# 📰 Generating example 237/300...
# ✅ Example 237 saved.
#
# 📰 Generating example 238/300...
# ✅ Example 238 saved.
#
# 📰 Generating example 239/300...
# ✅ Example 239 saved.
#
# 📰 Generating example 240/300...
# ✅ Example 240 saved.
#
# 📰 Generating example 241/300...
# ✅ Example 241 saved.
#
# 📰 Generating example 242/300...
# ✅ Example 242 saved.
#
# 📰 Generating example 243/300...
# ✅ Example 243 saved.
#
# 📰 Generating example 244/300...
# ⚠️ Attempt 1 failed: can only concatenate str (not "NoneType") to str
# ✅ Example 244 saved.
#
# 📰 Generating example 245/300...
# ✅ Example 245 saved.
#
# 📰 Generating example 246/300...
# ✅ Example 246 saved.
#
# 📰 Generating example 247/300...
# ✅ Example 247 saved.
#
# 📰 Generating example 248/300...
# ✅ Example 248 saved.
#
# 📰 Generating example 249/300...
# ✅ Example 249 saved.
#
# 📰 Generating example 250/300...
# ✅ Example 250 saved.
#
# 📰 Generating example 251/300...
# ✅ Example 251 saved.
#
# 📰 Generating example 252/300...
# ✅ Example 252 saved.
#
# 📰 Generating example 253/300...
# ✅ Example 253 saved.
#
# 📰 Generating example 254/300...
# ✅ Example 254 saved.
#
# 📰 Generating example 255/300...
# ✅ Example 255 saved.
#
# 📰 Generating example 256/300...
# ✅ Example 256 saved.
#
# 📰 Generating example 257/300...
# ✅ Example 257 saved.
#
# 📰 Generating example 258/300...
# ⚠️ Attempt 1 failed: can only concatenate str (not "NoneType") to str
# ✅ Example 258 saved.
#
# 📰 Generating example 259/300...
# ✅ Example 259 saved.
#
# 📰 Generating example 260/300...
# ✅ Example 260 saved.
#
# 📰 Generating example 261/300...
# ✅ Example 261 saved.
#
# 📰 Generating example 262/300...
# ✅ Example 262 saved.
#
# 📰 Generating example 263/300...
# ✅ Example 263 saved.
#
# 📰 Generating example 264/300...
# ✅ Example 264 saved.
#
# 📰 Generating example 265/300...
# ✅ Example 265 saved.
#
# 📰 Generating example 266/300...
# ✅ Example 266 saved.
#
# 📰 Generating example 267/300...
# ✅ Example 267 saved.
#
# 📰 Generating example 268/300...
# ✅ Example 268 saved.
#
# 📰 Generating example 269/300...
# ✅ Example 269 saved.
#
# 📰 Generating example 270/300...
# ✅ Example 270 saved.
#
# 📰 Generating example 271/300...
# ✅ Example 271 saved.
#
# 📰 Generating example 272/300...
# ✅ Example 272 saved.
#
# 📰 Generating example 273/300...
# ✅ Example 273 saved.
#
# 📰 Generating example 274/300...
# ✅ Example 274 saved.
#
# 📰 Generating example 275/300...
# ✅ Example 275 saved.
#
# 📰 Generating example 276/300...
# ✅ Example 276 saved.
#
# 📰 Generating example 277/300...
# ✅ Example 277 saved.
#
# 📰 Generating example 278/300...
# ✅ Example 278 saved.
#
# 📰 Generating example 279/300...
# ✅ Example 279 saved.
#
# 📰 Generating example 280/300...
# ✅ Example 280 saved.
#
# 📰 Generating example 281/300...
# ✅ Example 281 saved.
#
# 📰 Generating example 282/300...
# ✅ Example 282 saved.
#
# 📰 Generating example 283/300...
# ✅ Example 283 saved.
#
# 📰 Generating example 284/300...
# ✅ Example 284 saved.
#
# 📰 Generating example 285/300...
# ✅ Example 285 saved.
#
# 📰 Generating example 286/300...
# ✅ Example 286 saved.
#
# 📰 Generating example 287/300...
# ✅ Example 287 saved.
#
# 📰 Generating example 288/300...
# ✅ Example 288 saved.
#
# 📰 Generating example 289/300...
# ✅ Example 289 saved.
#
# 📰 Generating example 290/300...
# ✅ Example 290 saved.
#
# 📰 Generating example 291/300...
# ✅ Example 291 saved.
#
# 📰 Generating example 292/300...
# ✅ Example 292 saved.
#
# 📰 Generating example 293/300...
# ✅ Example 293 saved.
#
# 📰 Generating example 294/300...
# ✅ Example 294 saved.
#
# 📰 Generating example 295/300...
# ✅ Example 295 saved.
#
# 📰 Generating example 296/300...
# ✅ Example 296 saved.
#
# 📰 Generating example 297/300...
# ✅ Example 297 saved.
#
# 📰 Generating example 298/300...
# ✅ Example 298 saved.
#
# 📰 Generating example 299/300...
# ✅ Example 299 saved.
#
# 📰 Generating example 300/300...
# ✅ Example 300 saved.
#
# 🎉 Dataset generation complete. Saved to synthetic_news_dataset.jsonl
